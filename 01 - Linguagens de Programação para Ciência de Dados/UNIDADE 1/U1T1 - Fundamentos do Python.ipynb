# %% [markdown]
# # Tipos de Dados
# 1. Simples
#     1. Numéricos
#         1. Inteiro (int)
#         2. Ponto Flutuante (float)
#     2. Não-numéricos
#         1. Lógico/Booleano (boo)
#         2. Text/String (str)
# 2. Estruturais
#     1. Lista (list)
#     2. Tupla (tuple)
#     3. Faixa (range)
#     4. Discionário (dict)

# %% [markdown]
# # Identificadores
